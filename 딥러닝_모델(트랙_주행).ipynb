# %% [markdown]
# **구글 드라이브 연동**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **구글 코랩 기본 탑재 라이브러리 버전**

# %%
# !pip show tensorflow
# !pip show keras
# !pip show opencv-python
# Out:
# Name: tensorflow
# Version: 2.15.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: absl-py, astunparse, flatbuffers, gast, google-pasta, grpcio, h5py, keras, libclang, ml-dtypes, numpy, opt-einsum, packaging, protobuf, setuptools, six, tensorboard, tensorflow-estimator, tensorflow-io-gcs-filesystem, termcolor, typing-extensions, wrapt
# Required-by: dopamine_rl, tf_keras
# Name: keras
# Version: 2.15.0
# Summary: Deep learning for humans.
# Home-page: https://keras.io/
# Author: Keras team
# Author-email: keras-users@googlegroups.com
# License: Apache 2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires:
# Required-by: tensorflow
# Name: h5py
# Version: 3.9.0
# Summary: Read and write HDF5 files from Python
# Home-page:
# Author:
# ...

# %% [markdown]
# **사진 데이터 압축 해제 과정**

# %%
# !unzip -qq "/content/drive/MyDrive/기계종합설계/video.zip"

# %% [markdown]
# **# os 모듈**
#
# -운영 체제와 상호작용하려는 목적으로 사용 (윈도우 사용)
#
# -주요 기능 : 파일 및 디렉토리 조작, 환경 변수 관리, 프로세스 제어, (폴더, 파일)경로 조작 등
#
#  * 환경변수 - 운영체제와 소프트웨어가 서로 정보를 주고받기 위해 사용하는 '이름(환경변수 식별자)-값(변수에 저장된 실제 데이터)' 쌍
#
#  여기서는 주로 파일의 경로를 조작하는데 사용
#
# **# random 모듈**
#
# -난수 생성 및 임의의 요소를 선택하는 작업을 수행하는데 사용 (여러 장의 이미지 데이터를 랜덤 지정하기 위해)
#
# -주요 기능 : 난수 생성, 리스트에서 임의 요소 선택, 임의 순서로 리스트 섞기 등
#
# **# fnmatch 모듈**
#
# -파일 이름과 패턴(유닉스 스타일의 와일드카드를 사용하여 패턴화)을 비교하여 일치하는지 확인할 때 사용
#
#  * 와일드카드 : 와일드카드 문자를 포함한 패턴, 패턴은 특정 위치에 문자열을 대신하여 일치 여부를 판단함
#
#   * 가장 많이 사용되는 와일드카드 문자 : *, ?
#
#     *는 임의의 문자열과 일치, 예를들어 *.png 는 .png로 끝나는 모든 파일
#                                     코드 예시 : pattern = "*.png"
#    ?는 임의의 단일 문자와 일치, 예를들어 file?.txt는 file1.txt, file2.txt 등과 일치
#
# **# pickle 모듈**
#
# -파이썬 객체를 직렬화, 역직렬화하는데 사용
#
#  * 직렬화 : 파이썬 객체(리스트, 딕셔너리 등)를 파일에 저장하거나 네트워크를 통해 전송할 수 있는 형식(바이트 스트림)으로 변환하는 과정
#
#    wb는 쓰기 모드, 객체를 파일에 저장
#
#  * 역직렬화 : 바이트 스트림을 다시 파이썬 객체로 복원하는 과정
#
#    rb는 읽기 보드, 파일에서 객체를 읽어옴
#
#  * 바이트 스트림 : 데이터를 연속적인 바이트 단위로 표현한 것, 1바이트는 8비트로 구성
#
#   바이트 스트림으로 변환하는 이유 : 데이터의 저장과 전송의 효율성을 높이기 위함(저장 공간 절약, 전송 속도 향상)
#
#   0과1의 연속된 비트로 표현하여 컴퓨터 시스템이 쉽게 처리할 수 있음
#
# ----------------------------------
#
# **# numpy 라이브러리**
#
# 수치연산을 위한 라이브러리로 배열 및 행렬 연산에 주로 사용됨
#
# * set_printoptions 함수를 사용하여 배열의 출력 형식을 결정
#
# * lambda x : 익명의 함수를 생성
#
#     (lambda x : "%.4f" %x)이렇게 생성하면 입력값 x를 소수점 이하 4자리까지 출력
#
# * 딕셔너리 {키 : 값} 에서 키는 ('float_kind') , 값은 (lamba x : "%.4f" %x)
#
# **# pandas 라이브러리**
#
# 데이터 조작 및 분석을 위한 라이브러리
#
# * set_option : 데이터 출력(display) 옵션을 설정 - 텍스트
#
#     'display.width' : 데이터프레임을 출력할 때 한 줄(행)에 출력되는 최대 너비
#     'display.float_format' : float의 출력 형식 졀정
#         '{:,.4f}' .format : 데이터를 ',.4%' 형식으로 출력할 수 있도록 format(변환하여 출력)
#     'display.max_colwidth' : 데이터프레임의 각 컬럼(열)에 출력될 수 있는 최대 너비 설정
#
# **# tensorflow 라이브러리**
#
# 딥러닝 모델을 구축하고 훈련시키기 위한 오픈 소스 라이브러리
#
# * tensorflow.keras : tensorflow와 통합된 Keras 모듈을 불러옴, Keras는 딥러닝 모델을 쉽게 구축할 수 있는 고수준의 신경망 API(인터페이스)
#
# * Sequential : Keras의 모델 중 하나로 레이어를 순차적으로 쌓아 신경망을 구축하는데 사용 ('Nvidia_Model' 사용)
#
# * Conv2D, MaxPool2D, Dropout, Flatten, Dense : Keras의 여러 레이어 클레스(데이터 타입)
#
#     Conv2D는 2차원 컨볼루션 레이어로 이미지의 특징을 추출하는데 사용
#     MaxPool2D는 2차원 최대 풀링 레이어로 이미지의 공간 차원을 줄여서 계산량을 줄이고 중요한 특징을 강조
#     Dropout은 모델이 과적합 되는 것을 방지하기 위해 일부 뉴런을 무작위로 비활성화
#     Flatten은 평탄화 레이어로 다차원 입력을 1차원으로 변환
#     Dense는 밀집 연결 레이어로 완전 연결 신경망 레이어
#
# * Adam : Keras에서 제공하는 optimizer(최적화 알고리즘) 중 하나로 모델이 손실 함수를 최소화하는 방향으로 학습할 수 있도록 가중치를 조정
#
# * load_model : 훈련된 Keras 모델을 파일에서 로드하는데 사용
#
# -------------------------------
#
# **# scikit-learn 라이브러리**
#
# 머신러닝 라이브러리로 데이터 분석, 데이터 마이닝, 데이터 시각화 등 다양한 머신러닝 작업을 지원
#
# * shuffle : scikit-learn 라이브러리의 함수 중 하나로 배열 또는 행렬을 무작위로 섞어주는 역할(데이터의 순서가 예측 성능에 영향을 주지 않도록 무작위)
#
# * train_test_split : scikit-learn 라이브러리의 함수 중 하나로 데이터를 훈련 세트와 테스트 세트로 나누는 역할
#
# **# opencv 라이브러리**
#
# 컴퓨터 비전 및 이미지 처리 작업을 위한 라이브러리로 이미지 로드, 변환, 필터링, 객체 감지 등의 기능을 제공
#
# **# imgaug 라이브러리**
#
# 이미지 데이터 증강을 위한 라이브러리로 데이터를 무작위로 변형하여 모델의 일반화 성능을 향상시키는데 사용
#
# * augmenters : 증강(데이터를 다양한 방법으로 변형하고 보강하여 학습 데이터의 다양성을 증가시키는 것)을 수행하는 모듈로 딥러닝 모델 학습 시 중요한 역할
#
#     데이터 증강 방법 : 이미지를 무작위로 회전, 반전, 크기 조절, 색상 변형 등
#
# **# matplotlib 라이브러리**
#
# 데이터 시각화를 위한 라이브러리로 그래프, 플롯, 이미지 표시 등 다양한 시각화 기능 제공
#
# * pyplot : matplotlib 라이브러리의 모듈 중 하나로 데이터를 시각화하기 위한 그래픽 기능 제공
#
#     주로 2D그래픽을 생성하고 조작
#     선 그래프, 막대 그래프, 히스토그램 등을 그릴 수 있으며 축의 레이블, 제목 등의 요소 추가 가능
#
# * image : matplotlib 라이브러리의 모듈 중 하나로 이미지 파일을 로드하고 표시하는 기능을 제공
#
#     Figure 객체(전체 그림의 레이아웃 스타일을 설정하는데 사용)에 추가하여 다른 그래픽 요소(크기 조정 등)와 함께 표시 가능
#
#
# **# %matplotlib inline** 코드 부연 설명
#
# 주피터 노트북에서 matplotlib을 사용하여 생성된 그림을 인라인으로 표시하도록 설정하여 코드 실행 결과 바로 그림 확인 가능하도록 함
#
# **# PIL 라이브러리**
#
# 이미지 처리와 조작을 위한 라이브러리
#
# 이미지 파일을 열고 / 저장하고 / 크기 조정하고 / 회전시키고 / 필터를 적용하는 등 다양한 작업 수행 가능
#
# * Image : PIL 라이브러리에서 제공하는 모듈 중 하나로 이미지 파일을 열고 이미지 객체를 생성하며 이미지를 조작하는데 사용

# %%
import os
import random
import fnmatch
import pickle

import numpy as np
np.set_printoptions(formatter = {'float_kind' : lambda x : "%.4f" %x})

import pandas as pd
pd.set_option('display.width', 300)
pd.set_option('display.float_format', '{:,.4f}' .format)
pd.set_option('display.max_colwidth', 200)

import tensorflow as tf
import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D, Dropout, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import load_model

print(f'tf.__version__: {tf.__version__}')
#print(f' .keras.__version__: {tensorflow.keras.__version__}')
print("keras version: ", keras.__version__)

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

import cv2
from imgaug import augmenters as img_aug
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
from PIL import Image
# Out:
# tf.__version__: 2.15.0
# keras version:  2.15.0

# %% [markdown]
# **데이터 불러오기**
#
# -코드 추가 설명
# * os.path.join() : 여러 경로 구성 요소를 연결하여 단일 경로로 변경
#
#     여기서는 data_dir이 '/content/Videos'이고 filename이 'train_00000_090.png' 이므로 '/content/Videos/train_00000_090.png' 와 같은 경로 생성
#
# * DataFrame() : 데이터 프레임은 행과 열로 구성된 테이블 형식의 데이터 구조
#
#     여기서 빈 데이터 프레임을 생성하고 df [ 'ImagePath' ] = image_paths 와 df [ 'Angle' ] = steering_angles 코드를 사용해 데이터 프레임에 이미지 경로와 조향각 정보를 각각 열에 추가

# %%
data_dir = '/content/Videos'                                           # video.zip파일을 압축 해제하고 생성된 Videos파일로 폴더 경로를 지정해줌
file_list = os.listdir(data_dir)                                       # os.listidir() 함수를 사용해 data_dir에 지정된 폴더 내의 파일 목록을 가져옴
image_paths = []                                                       # 이미지 파일의 경로를 저장할 빈 리스트 생성
steering_angles = []                                                   # 조향각 정보를 저장할 빈 리스트 생성
pattern = "*.png"                                                      # 파일명에 '.png'가 포함된 파일을 fnmatch모듈로 찾기 위해 'pattern'변수에 넣어줌

for filename in file_list:                                             # file_list에 있는 각 파일 이름에 대해 '*.png'이 있는 파일을 확인
    if fnmatch.fnmatch(filename, pattern):
        image_paths.append(os.path.join(data_dir,filename))            # 생성해뒀던 빈 리스트 'image_paths'에 'data_dir'과 'filename'을 합친 경로를 추가
        angle=int(filename[-7:-4])                                     # 파일 이름의 끝에서 7번째부터 5번째까지 추출하여 'angle' 변수에 저장
        steering_angles.append(angle)                                  # 생성해뒀던 빈 리스트 'steering_angles'에 'angle'값 추가

image_index=100                                                        # 100번째 이미지 경로와 각도, 이미지를 출력해보기 위해 인덱스 지정
plt.imshow(Image.open(image_paths[image_index]))                       # 해당 인덱스의 이미지 경로를 열어 이미지를 시각화
print(" image_path :%s" % image_paths[image_index])                     # 해당 인덱스의 이미지 경로를 출력
print(" steering_Angle: %d" % steering_angles[image_index])             # 해당 인덱스의 조향각 정보를 출력

df = pd.DataFrame()                                                    # 'df'라는 빈 데이터 프레임 생성
df['ImagePath'] = image_paths                                          # 'df'에 'ImagePath'열을 생성하여 이미지경로 추가
df['Angle'] = steering_angles                                          # 'df'에 'Angle'열을 생성하여 조향각 정보 추가
# Out:
#  image_path :/content/Videos/train_01214_135.png
#  steering_Angle: 135

# %%
df['ImagePath'][100]                                                       # 20번째 이미지의 경로와 위 출력된 이미지 경로가 동일한 것을 볼 수 있다.
# Out:
# '/content/Videos/train_01214_135.png'

# %%
df                                                                     # 전체 이미지 개수는 7666개
# Out:
#                                 ImagePath  Angle
# 0     /content/Videos/train_01429_135.png    135
# 1     /content/Videos/train_03317_090.png     90
# 2     /content/Videos/train_04355_090.png     90
# 3     /content/Videos/train_02345_090.png     90
# 4     /content/Videos/train_00578_090.png     90
# ...                                   ...    ...
# 7661  /content/Videos/train_02257_135.png    135
# 7662  /content/Videos/train_05021_090.png     90
# 7663  /content/Videos/train_03844_090.png     90
# 7664  /content/Videos/train_01323_090.png     90
# 7665  /content/Videos/train_00694_135.png    135
#
# [7666 rows x 2 columns]

# %%
df_sort = df.sort_values(by = 'ImagePath')
print(df_sort)
# Out:
#                                 ImagePath  Angle
# 3653  /content/Videos/train_00000_090.png     90
# 5196  /content/Videos/train_00001_090.png     90
# 51    /content/Videos/train_00002_090.png     90
# 337   /content/Videos/train_00003_090.png     90
# 7511  /content/Videos/train_00004_090.png     90
# ...                                   ...    ...
# 7387  /content/Videos/train_07661_090.png     90
# 835   /content/Videos/train_07662_090.png     90
# 7576  /content/Videos/train_07663_090.png     90
# 2931  /content/Videos/train_07664_090.png     90
# 5040  /content/Videos/train_07665_090.png     90
#
# [7666 rows x 2 columns]

# %% [markdown]
# **조향각에 따른 이미지 개수 시각화**
#
# 히스토그램은 데이터의 분포를 시각화하는데 사용하며 빈(bins)의 수가 많을수록 데이터의 세부적인 분포를 더 잘 보여줌
#
#     빈(bins) : 데이터를 일정한 간격으로 나누는 구간
#
#         조향각은 3가지인데 3이 아닌 25로 하는 이유는 3으로 하면 각도축에서 45-135도를 단순 3등분 해버리기 때문에 실제 값과 차이를 보임
#         따라서 25등분 정도가 적정함
#
# Figure : matplotlib에서 그림 전체를 의미, Figure에는 하나 이상의 서브플롯이 존재할 수 있음
#
#     서브플롯 : Figure내에 위치한 개별적인 그래프 영역으로 행과 열로 정의됨
#
#               행이 2이고 열이 2이면 2*2 = 4, 4개의 서브플롯
#               여기서는 조향각에 대해서 개수를 표현하는 그래프 이므로 단일 서브플롯

# %%
num_of_bins = 30                                                   # 히스토그램을 그릴 때 사용하는 빈(bins)의 개수를 지정하기 위해 생성한 변수
hist, bins = np.histogram(df['Angle'], num_of_bins)                # 데이터프레임에 포함된 'Angle' 열(column) 데이터를 가져와 hist에 할당, bins에 num_of_bins 할당

fig, axes = plt.subplots(1, 1, figsize=(12, 4))                    # 1, 1 이므로 단일 서브플롯 / figsixe = (12, 4)는 크기 설정 - 너비가 12인치, 높이가 4인치
axes.hist(df['Angle'], bins=num_of_bins, width=1, color='blue')    # df['Angle']데이터를 사용해 bins는 num_of_bins, 막대 너비는 1, 색은 blue로 지정해서 히스토그램 생성

angles = [45.4, 90.5, 132.4]

plt.title('Number of Image by angle')
plt.ylabel('image_count')
plt.xlabel('steering_angles')
plt.xticks(angles, ['45(left)', '90(straight)', '135(right)'])
# Out:
# ([<matplotlib.axis.XTick at 0x7ca5528d22f0>,
# ...
#  [Text(45.4, 0, '45(left)'),
#   Text(90.5, 0, '90(straight)'),
#   Text(132.4, 0, '135(right)')])

# %% [markdown]
# train_test_split()을 사용해 image_paths(이미지 경로)와 steering_angles(조향각) 데이터를 학습용 데이터와 검증용 데이터로 분할
#
# 검증용 데이터는 0.2(20%) 정도로 정함, 데이터 셋을 나눌 때 일반적으로 '학습:검증'을 7:3이나 8:2로 많이 나눔
#
# X_train = 학습용 이미지 경로, X_valid = 검증용 이미지 경로, y_train = 학습용 조향각, y_valid = 검증용 조향각

# %%
X_train, X_valid, y_train, y_valid = train_test_split(image_paths, steering_angles, test_size = 0.2)
print(" Training data: %d\n Validation data: %d" % (len(X_train), len(X_valid)))
# Out:
#  Training data: 6132
#  Validation data: 1534

# %%
X_train, X_valid, y_train, y_valid = train_test_split(image_paths, steering_angles, test_size = 0.2)
print(" Training data: %d\n Validation data: %d" % (len(X_train), len(X_valid)))

fig, axes = plt.subplots(1, 2, figsize = (12,4))
axes[0].hist(y_train, bins=num_of_bins, width=1, color='blue')
axes[0].set_title('Training Data')
axes[0].set_xlabel('steering_angles')
axes[0].set_ylabel('image_count')
axes[0].set_xticks(angles)
axes[0].set_xticklabels(['45(left)', '90(straight)', '135(right)'])
axes[1].hist(y_valid, bins=num_of_bins, width=1, color='red')
axes[1].set_title('Validation Data')
axes[1].set_xlabel('steering_angles')
axes[1].set_xticks(angles)
axes[1].set_xticklabels(['45(left)', '90(straight)', '135(right)'])

angles = [45.4, 90.5, 132.4]
# Out:
#  Training data: 6132
#  Validation data: 1534

# %%
# X는 학습_이미지 경로 데이터
X_train_data = X_train[:5]     # 상위 5개만 추출
X_train_data = pd.DataFrame(X_train_data, columns = ['X_train_data'])
X_train_data
# Out:
#                           X_train_data
# 0  /content/Videos/train_05483_090.png
# 1  /content/Videos/train_00603_090.png
# 2  /content/Videos/train_07225_090.png
# 3  /content/Videos/train_04170_045.png
# 4  /content/Videos/train_03735_135.png

# %%
# X는 검증_이미지 경로 데이터
X_valid_data = X_valid[:5]     # 상위 5개만 추출
X_valid_data = pd.DataFrame(X_valid_data, columns = ['X_valid_data'])
X_valid_data
# Out:
#                           X_valid_data
# 0  /content/Videos/train_07062_045.png
# 1  /content/Videos/train_05833_045.png
# 2  /content/Videos/train_06447_045.png
# 3  /content/Videos/train_06643_045.png
# 4  /content/Videos/train_05810_045.png

# %%
# y는 학습_조향각 데이터
y_train_data = y_train[:5]     # 상위 5개만 추출
y_train_data = pd.DataFrame(y_train_data, columns = ['y_train_data'])
y_train_data
# Out:
#    y_train_data
# 0            90
# 1            90
# 2            90
# 3            45
# 4           135

# %%
# y는 검증_조향각 데이터
y_valid_data = y_valid[:5]     # 상위 5개만 추출
y_valid_data = pd.DataFrame(y_valid_data, columns = ['y_valid_data'])
y_valid_data
# Out:
#    y_valid_data
# 0            45
# 1            45
# 2            45
# 3            45
# 4            45

# %% [markdown]
# 정규화를 255로 해주는 이유 : 보통 이미지의 픽셀 값은 0부터 255까지의 범위에 있음. 이를 255로 나눔으로서 0부터 1사이의 값으로 바꿔 좀 더 안정적으로 학습될 수 있도록 해줌
#
# 스케일링을 해주면 최적화 알고리즘이 더 잘 작동할 수 있음
#
# 0과 1사이로 스케일링을 해주는 이유는 일부 활성화 함수(시그모이드, 소프트맥스 등)은 0과 1사이에서 최적으로 동작함
#
#     데이터 스케일링이 작을수록 최적화 알고리즘이 더 빠르게 수렴할 수 있어 입력 데이터를 작은 범위로 스케일링 하면 학습 속도를 향상시킬 수 있음
#     학습의 안전성에 있어서도 작은 스케일의 데이터는 오버피팅을 방지하고 학습 과정을 안정화할 수 있음
#
#         * 오버피팅 : 기계학습에서 발생하는 부요 문제 중 하나로 모델이 훈련 데이터에 대해서는 잘 작동하지만 새로운 데이터에 대해서는 성능이 떨어지는 현상
#
#                    오버피팅이 발생하면 모델이 훈련 데이터의 노이즈나 특정한 패턴을 학습하여 새로운 데이터에 대한 일반화 능력이 저하됨
#                    원인으로는 너무 많은 훈련 에포크, 훈련 데이터의 부족, 복잡한 모델 구조 등이 있다.
#                    훈련 데이터의 양을 늘리거나 모델을 단순화하거나 드롭 아웃 등을 통해 방지할 수 있다.
#
#                    *Dropout : 모델이 과적합 되는 것을 방지하기 위해 일부 뉴런을 무작위로 비활성화

# %%
def my_imread(image_path):
    image = cv2.imread(image_path)
    return image

def img_preprocess(image):
  image = image / 255
  return image

fig, axes = plt.subplots(1, 2, figsize = (15, 10))
image_orig = my_imread(image_paths[image_index])
image_processed = img_preprocess(image_orig)
axes[0].imshow(image_orig)
axes[0].set_title("orig")
axes[1].imshow(image_processed)
axes[1].set_title("processed")
# Out:
# Text(0.5, 1.0, 'processed')

# %% [markdown]
# **# Nvidia 모델**
#
# NVIDIA 모델은 자율주행 차량의 차선 인식, 장애물 회피, 경로 계획 등의 작업에서 높은 성능을 발휘
# 고성능 GPU와 최적화된 소프트웨어 스택을 통해 실시간 비전 작업을 효율적으로 수행할 수 있으며, 자율주행 차량, 드론, 로보틱스 등 다양한 분야에서 사용
#
#
# ```
# NVIDIA 모델은 자율주행 시스템에서 다양한 역할을 수행
#
# 1. 차선 인식 : 도로의 차선을 인식하고 차량이 차선 내에서 주행할 수 있도록 도움을 줌
#
# 2. 장애물 회피 : 실시간으로 장애물을 감지하고 이를 회피하는 경로를 계획
#
# 3. 경로 계획 : 카메라 및 센서 데이터를 바탕으로 차량의 주행 경로를 계획
#
# 4. 스티어링 제어 : 모델이 예측한 경로에 따라 차량의 스티어링을 제어하여 안전한 주행을 유지
# ```

# %%
def nvidia_model():
    model = Sequential(name = 'Nvidia_Model')

    model.add(Conv2D(24, (5, 5), strides=(2, 2), input_shape = (66, 200, 3), activation = 'elu'))
    model.add(Conv2D(36, (5, 5), strides=(2, 2), activation = 'elu'))
    model.add(Conv2D(48, (5, 5), strides=(2, 2), activation = 'elu'))
    model.add(Conv2D(64, (3, 3), activation = 'elu'))
    model.add(Dropout(0.2))
    model.add(Conv2D(64, (3, 3), activation = 'elu'))

    model.add(Flatten())
    model.add(Dropout(0.2))
    model.add(Dense(100, activation = 'elu'))
    model.add(Dense(50, activation = 'elu'))
    model.add(Dense(10, activation = 'elu'))

    model.add(Dense(1))

    optimizer=Adam(learning_rate=0.001)
    model.compile(loss = 'mse', optimizer = optimizer)

    return model

model = nvidia_model()
print(model.summary())
# Out:
# Model: "Nvidia_Model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 31, 98, 24)        1824
#
#  conv2d_1 (Conv2D)           (None, 14, 47, 36)        21636
#
#  conv2d_2 (Conv2D)           (None, 5, 22, 48)         43248
#
#  conv2d_3 (Conv2D)           (None, 3, 20, 64)         27712
#
#  dropout (Dropout)           (None, 3, 20, 64)         0
#
#  conv2d_4 (Conv2D)           (None, 1, 18, 64)         36928
#
#  flatten (Flatten)           (None, 1152)              0
#
#  dropout_1 (Dropout)         (None, 1152)              0
#
#  dense (Dense)               (None, 100)               115300
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 10)                510
#
#  dense_3 (Dense)             (None, 1)                 11
#
# ...
# Total params: 252219 (985.23 KB)
# Trainable params: 252219 (985.23 KB)
# ...

# %% [markdown]
# batch : 머신러닝이나 딥러닝에서 모델을 학습시키기 위해 데이터를 소규모 그룹으로 나누어 처리하는 방법
#
# batch_size : 한번의 학습단계에서 사용되는 데이터 샘플의 수
#  * batch_size = 100이라면 한번의 학습단계에서 100개의 데이터 샘플을 사용하여 가중치를 업데이트 함
#
#
#
# ```
# <배치 크기가 100, 전체 데이터가 7666개, 1 에포크 동안 300번의 학습 단계를 가지는 경우>
# 300번의 학습 단계 동안 매 단계마다 100개의 데이터 샘플을 무작위로 선택
#
# 한 에포크에서 300번의 학습단계 중 첫 번째 단계에서 100개의 랜덤 데이터 샘플을 사용하여 가중치를 업데이트함
#
# 그 과정을 300번 반복하는 것이 1 에포크
#
# 한 에포크 과정을 10번 반복하여 학습
# ```
# 데이터를 증강하여 진행할 수도 있지만 랜덤 추출을 하여 증강 없이 사용
#
# 결론적으로 중복을 허용하여 30000개의 데이터 샘플을 사용한 것이 됨.

# %%
def image_data_generator(image_paths, steering_angles, batch_size):
    while True:
        batch_images = []
        batch_steering_angles = []

        for i in range(batch_size):
            random_index = random.randint(0, len(image_paths) - 1)
            image_path = image_paths[random_index]
            image = my_imread(image_paths[random_index])
            steering_angle = steering_angles[random_index]

            image = img_preprocess(image)
            batch_images.append(image)
            batch_steering_angles.append(steering_angle)

        yield(np.asarray(batch_images), np.asarray(batch_steering_angles))

X_train_batch, y_train_batch = next(image_data_generator(X_train, y_train, nrow))
X_valid_batch, y_valid_batch = next(image_data_generator(X_valid, y_valid, nrow))

ncol = 2
nrow = 2

fig, axes = plt.subplots(nrow, ncol, figsize = (15,6))
fig.tight_layout()

for i in range(nrow):
    axes[i][0].imshow(X_train_batch[i])
    axes[i][0].set_title("training, angle = %s" % y_train_batch[i])
    axes[i][1].imshow(X_valid_batch[i])
    axes[i][1].set_title("validation, angle = %s" % y_valid_batch[i])

# %%
model_output_dir = "/content/drive/MyDrive/기계종합설계"

checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath = os.path.join(model_output_dir, 'lane_navigation_check.keras'), verbose = 1, save_best_only = True)

history = model.fit(image_data_generator(X_train, y_train, batch_size = 100),
                    steps_per_epoch = 300, epochs = 10, validation_data = image_data_generator(X_valid, y_valid, batch_size = 100),
                    validation_steps = 200, verbose = 1, shuffle = 1, callbacks = [checkpoint_callback])

model.save(os.path.join(model_output_dir, 'lane_navigation_final.keras'))

history_path = os.path.join(model_output_dir, 'history.pickle')
with open(history_path, 'wb') as f:
    pickle.dump(history.history, f, pickle.HIGHEST_PROTOCOL)
# Out:
# Epoch 1/15
#  28/300 [=>............................] - ETA: 1:04 - loss: 54.6288
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a95d398caf13> in <cell line: 5>()
#       3 checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath = os.path.join(model_output_dir, 'lane_navigation_check.keras'), verbose = 1, save_best_only = True)
#       4
# ----> 5 history = model.fit(image_data_generator(X_train, y_train, batch_size = 100),
#       6                     steps_per_epoch = 300, epochs = 15, validation_data = image_data_generator(X_valid, y_valid, batch_size = 100),
#       7                     validation_steps = 200, verbose = 1, shuffle = 1, callbacks = [checkpoint_callback])
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ...

# %%
history.history

history_path = os.path.join(model_output_dir, 'history.pickle')
with open(history_path, 'rb') as f:
    history = pickle.load(f)

history
plt.plot(history['loss'], color = 'blue')
plt.plot(history['val_loss'], color = 'red')
plt.legend(["training loss", "validation loss"])

# %%
from sklearn.metrics import mean_squared_error, r2_score

def summarize_prediction (Y_true, Y_pred):                                   # Y_true(실제 값)과 Y_pred(예측 값)으로 mse(평균 제곱 오차)와 r_squared(결정계수)를 계산하는 함수

    mse=mean_squared_error(Y_true, Y_pred)
    r_squared=r2_score(Y_true, Y_pred)

    print(f'mse={mse:2}')
    print(f'r_squared={r_squared:.2%}')
    print()

def predict_and_summarize(X,Y):                                              # 최종 모델을 불러와 X와 Y로 X에 대한 예측을 수행하고 그 값을 Y_pred에 저장
    model=load_model(f'{model_output_dir}/lane_navigation_final.keras')      # 저장된 Y_pred(예측값)와 Y(실제 값)를 사용해 위 함수(mse와 r_squared)를 계산
    Y_pred=model.predict(X)
    summarize_prediction(Y,Y_pred)
    return Y_pred

n_tests=100
X_test, y_test=next(image_data_generator(X_valid,y_valid,100))               # batch_size = 100에 해당하는 데이터를 각각 X_test(경로), y_test(각도)에 저장

y_pred=predict_and_summarize(X_test,y_test)                                  # y_test(각도)와 X_test(경로)를 바탕으로 y_pred(예측 각도)를 만들고 y_test와 y_pred 비교

n_tests_show=2
fig,axes=plt.subplots(n_tests_show,1,figsize=(10,4*n_tests_show))
for i in range(n_tests_show):
    axes[i].imshow(X_test[i])
    axes[i].set_title(f"actual angle={y_test[i]}, predicted angle={int(y_pred[i])},diff={int(y_pred[i])-y_test[i]}")
# Out:
# 4/4 [==============================] - 0s 10ms/step
# mse=36.61882209337273
# r_squared=95.67%
# <ipython-input-19-a67cb94f048b>:27: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   axes[i].set_title(f"actual angle={y_test[i]}, predicted angle={int(y_pred[i])},diff={int(y_pred[i])-y_test[i]}")
